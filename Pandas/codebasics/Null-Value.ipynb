# %%
import pandas as pd 
import numpy as np

# %%
data = np.random.randn(10, 3)
for col in range(data.shape[1]):
    null_indices = np.random.choice(10,3, replace=False)
    data[null_indices, col] = np.nan
df = pd.DataFrame(data, columns=['A', 'B', 'C'])

# %%
df
# Out:
#           A         B         C
# 0       NaN -0.733138  0.536628
# 1       NaN  0.041463 -0.038624
# 2  0.017109 -0.436760       NaN
# 3 -0.532118       NaN -1.226759
# 4  0.070412       NaN  0.994779
# 5  1.011214  0.632542       NaN
# 6  0.012131  1.011563  0.296728
# 7  1.050126       NaN       NaN
# 8       NaN  0.446908  1.355672
# 9 -1.311295  0.395434 -2.176557

# %%
df.head()
# Out:
#           A         B         C
# 0       NaN -0.733138  0.536628
# 1       NaN  0.041463 -0.038624
# 2  0.017109 -0.436760       NaN
# 3 -0.532118       NaN -1.226759
# 4  0.070412       NaN  0.994779

# %%
# check nan value
pd.isna(df['A'])
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8     True
# 9    False
# Name: A, dtype: bool

# %%
pd.isna(df)
# Out:
#        A      B      C
# 0   True  False  False
# 1   True  False  False
# 2  False  False   True
# 3  False   True  False
# 4  False   True  False
# 5  False  False   True
# 6  False  False  False
# 7  False   True   True
# 8   True  False  False
# 9  False  False  False

# %%
pd.notna(df)
# Out:
#        A      B      C
# 0  False   True   True
# 1  False   True   True
# 2   True   True  False
# 3   True  False   True
# 4   True  False   True
# 5   True   True  False
# 6   True   True   True
# 7   True  False  False
# 8  False   True   True
# 9   True   True   True

# %%
df.isnull()
# Out:
#        A      B      C
# 0   True  False  False
# 1   True  False  False
# 2  False  False   True
# 3  False   True  False
# 4  False   True  False
# 5  False  False   True
# 6  False  False  False
# 7  False   True   True
# 8   True  False  False
# 9  False  False  False

# %%
df.isnull().sum()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       7 non-null      float64
#  1   B       7 non-null      float64
#  2   C       7 non-null      float64
# dtypes: float64(3)
# memory usage: 372.0 bytes

# %%
# Handling NaN values
df
# Out:
#           A         B         C
# 0       NaN -0.733138  0.536628
# 1       NaN  0.041463 -0.038624
# 2  0.017109 -0.436760       NaN
# 3 -0.532118       NaN -1.226759
# 4  0.070412       NaN  0.994779
# 5  1.011214  0.632542       NaN
# 6  0.012131  1.011563  0.296728
# 7  1.050126       NaN       NaN
# 8       NaN  0.446908  1.355672
# 9 -1.311295  0.395434 -2.176557

# %%
df.isnull().sum()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df.median()
# Out:
# A    0.017109
# B    0.395434
# C    0.296728
# dtype: float64

# %%
df.fillna(df.median())
# Out:
#           A         B         C
# 0  0.017109 -0.733138  0.536628
# 1  0.017109  0.041463 -0.038624
# 2  0.017109 -0.436760  0.296728
# 3 -0.532118  0.395434 -1.226759
# 4  0.070412  0.395434  0.994779
# 5  1.011214  0.632542  0.296728
# 6  0.012131  1.011563  0.296728
# 7  1.050126  0.395434  0.296728
# 8  0.017109  0.446908  1.355672
# 9 -1.311295  0.395434 -2.176557

# %%
df.fillna({
    'A': 0,
    'B': 1,
    'C': 2
})
# Out:
#           A         B         C
# 0  0.000000 -0.733138  0.536628
# 1  0.000000  0.041463 -0.038624
# 2  0.017109 -0.436760  2.000000
# 3 -0.532118  1.000000 -1.226759
# 4  0.070412  1.000000  0.994779
# 5  1.011214  0.632542  2.000000
# 6  0.012131  1.011563  0.296728
# 7  1.050126  1.000000  2.000000
# 8  0.000000  0.446908  1.355672
# 9 -1.311295  0.395434 -2.176557

# %%
df.dropna()
# Out:
#           A         B         C
# 6  0.012131  1.011563  0.296728
# 9 -1.311295  0.395434 -2.176557

# %%
df
# Out:
#           A         B         C
# 0       NaN -0.733138  0.536628
# 1       NaN  0.041463 -0.038624
# 2  0.017109 -0.436760       NaN
# 3 -0.532118       NaN -1.226759
# 4  0.070412       NaN  0.994779
# 5  1.011214  0.632542       NaN
# 6  0.012131  1.011563  0.296728
# 7  1.050126       NaN       NaN
# 8       NaN  0.446908  1.355672
# 9 -1.311295  0.395434 -2.176557

# %%
df.dropna(how='all')
# Out:
#           A         B         C
# 0       NaN -0.733138  0.536628
# 1       NaN  0.041463 -0.038624
# 2  0.017109 -0.436760       NaN
# 3 -0.532118       NaN -1.226759
# 4  0.070412       NaN  0.994779
# 5  1.011214  0.632542       NaN
# 6  0.012131  1.011563  0.296728
# 7  1.050126       NaN       NaN
# 8       NaN  0.446908  1.355672
# 9 -1.311295  0.395434 -2.176557

# %%
df.dropna(how='any')
# Out:
#           A         B         C
# 6  0.012131  1.011563  0.296728
# 9 -1.311295  0.395434 -2.176557

# %%
df.dropna(thresh=2)
# Out:
#           A         B         C
# 0       NaN -0.733138  0.536628
# 1       NaN  0.041463 -0.038624
# 2  0.017109 -0.436760       NaN
# 3 -0.532118       NaN -1.226759
# 4  0.070412       NaN  0.994779
# 5  1.011214  0.632542       NaN
# 6  0.012131  1.011563  0.296728
# 8       NaN  0.446908  1.355672
# 9 -1.311295  0.395434 -2.176557

# %%
df.dropna(thresh=3)
# Out:
#           A         B         C
# 6  0.012131  1.011563  0.296728
# 9 -1.311295  0.395434 -2.176557

# %%
df.dropna(thresh=4)
# Out:
# Empty DataFrame
# Columns: [A, B, C]
# Index: []

# %%
df
# Out:
#           A         B         C
# 0       NaN -0.733138  0.536628
# 1       NaN  0.041463 -0.038624
# 2  0.017109 -0.436760       NaN
# 3 -0.532118       NaN -1.226759
# 4  0.070412       NaN  0.994779
# 5  1.011214  0.632542       NaN
# 6  0.012131  1.011563  0.296728
# 7  1.050126       NaN       NaN
# 8       NaN  0.446908  1.355672
# 9 -1.311295  0.395434 -2.176557

# %%
df.fillna({
    'A': 'E',
    'B': 'F',
    'C': 'G'
})
# Out:
#           A         B         C
# 0         E -0.733138  0.536628
# 1         E  0.041463 -0.038624
# 2  0.017109  -0.43676         G
# 3 -0.532118         F -1.226759
# 4  0.070412         F  0.994779
# 5  1.011214  0.632542         G
# 6  0.012131  1.011563  0.296728
# 7  1.050126         F         G
# 8         E  0.446908  1.355672
# 9 -1.311295  0.395434 -2.176557

# %%
from IPython.display import Image

# %%
df.fillna(df.mean())
# Out:
#           A         B         C
# 0  0.045368 -0.733138  0.536628
# 1  0.045368  0.041463 -0.038624
# 2  0.017109 -0.436760 -0.036876
# 3 -0.532118  0.194002 -1.226759
# 4  0.070412  0.194002  0.994779
# 5  1.011214  0.632542 -0.036876
# 6  0.012131  1.011563  0.296728
# 7  1.050126  0.194002 -0.036876
# 8  0.045368  0.446908  1.355672
# 9 -1.311295  0.395434 -2.176557

# %%
df.mean()
# Out:
# A    0.045368
# B    0.194002
# C   -0.036876
# dtype: float64
