# %%
import pandas as pd 
import requests
from io import StringIO

# %%
url = 'https://raw.githubusercontent.com/rashakil-ds/5-Minutes-to-Pandas/refs/heads/main/Datasets/automobile.csv'
response = requests.get(url)

# %%
csv_data = StringIO(response.text)

# %%
df = pd.read_csv(csv_data)
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
df.shape
# Out:
# (202, 26)

# %%
row, col = df.shape

# %%
row
# Out:
# 202

# %%
col
# Out:
# 26

# %%
df.head(2)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
#
#    peak-rpm city-mpg highway-mpg  price
# 0      5000       21          27  13495
# 1      5000       21          27  16500
#
# [2 rows x 26 columns]

# %%
df.tail(2)
# Out:
#      symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1               95.0  volvo       gas      turbo         four
# 201         -1               95.0  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 200         mpfi  3.78    3.15               9.5        114      5400
# 201         mpfi  3.78    3.15               9.5        114      5400
#
#     city-mpg highway-mpg  price
# 200       19          25  22625
# 201       19          25  22625
#
# [2 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          202 non-null    int64
#  1   normalized-losses  165 non-null    float64
#  2   make               202 non-null    object
#  3   fuel-type          202 non-null    object
#  4   aspiration         202 non-null    object
#  5   num-of-doors       200 non-null    object
#  6   body-style         202 non-null    object
#  7   drive-wheels       202 non-null    object
#  8   engine-location    202 non-null    object
#  9   wheel-base         202 non-null    float64
#  10  length             202 non-null    float64
#  11  width              202 non-null    float64
#  12  height             202 non-null    float64
#  13  curb-weight        202 non-null    int64
#  14  engine-type        202 non-null    object
#  15  num-of-cylinders   202 non-null    object
# ...

# %%
df[5:10]
# Out:
#    symboling  normalized-losses  make fuel-type aspiration num-of-doors  \
# 5          2                NaN  audi       gas        std          two
# 6          1              158.0  audi       gas        std         four
# 7          1                NaN  audi       gas        std         four
# 8          1              158.0  audi       gas      turbo         four
# 9          2              192.0   bmw       gas        std          two
#
#   body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 5      sedan          fwd           front        99.8  ...          136
# 6      sedan          fwd           front       105.8  ...          136
# 7      wagon          fwd           front       105.8  ...          136
# 8      sedan          fwd           front       105.8  ...          131
# 9      sedan          rwd           front       101.2  ...          108
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# ...

# %%
df['make']
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
#           ...
# 197          volvo
# 198          volvo
# 199          volvo
# 200          volvo
# 201          volvo
# Name: make, Length: 202, dtype: object

# %%
df.make
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
#           ...
# 197          volvo
# 198          volvo
# 199          volvo
# 200          volvo
# 201          volvo
# Name: make, Length: 202, dtype: object

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df[['make', 'price', 'length', 'horsepower']].head()
# Out:
#           make  price  length horsepower
# 0  alfa-romero  13495   168.8        111
# 1  alfa-romero  16500   168.8        111
# 2  alfa-romero  16500   171.2        154
# 3         audi  13950   176.6        102
# 4         audi  17450   176.6        115

# %%
type(df['price'])
# Out:
# pandas.core.series.Series

# %%
df[['symboling', 'normalized-losses', 'make', 'fuel-type']][1:11]
# Out:
#     symboling  normalized-losses         make fuel-type
# 1           3                NaN  alfa-romero       gas
# 2           1                NaN  alfa-romero       gas
# 3           2              164.0         audi       gas
# 4           2              164.0         audi       gas
# 5           2                NaN         audi       gas
# 6           1              158.0         audi       gas
# 7           1                NaN         audi       gas
# 8           1              158.0         audi       gas
# 9           2              192.0          bmw       gas
# 10          0              192.0          bmw       gas
