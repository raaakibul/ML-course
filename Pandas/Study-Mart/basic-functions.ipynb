# %%
import pandas as pd
import requests
from io import StringIO

# %%
url ='https://raw.githubusercontent.com/rashakil-ds/5-Minutes-to-Pandas/refs/heads/main/Datasets/Screen%20Time%20Data.csv'
response = requests.get(url)

# %%
csv_data = StringIO(response.text)

# %%
df = pd.read_csv(csv_data)
df
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 1       1  04/18/19   Thursday                 123                 78
# 2       2  04/19/19     Friday                 112                 52
# 3       3  04/20/19   Saturday                 101                 69
# 4       4  04/21/19     Sunday                  56                 35
# 5       5  04/22/19     Monday                 189                 68
# 6       6  04/23/19    Tuesday                 158                 56
# 7       7  04/24/19  Wednesday                 135                 98
# 8       8  04/25/19   Thursday                  52                 25
# 9       9  04/26/19     Friday                 198                 76
# 10     10  04/27/19   Saturday                 116                 75
# 11     11  04/28/19     Sunday                  85                 42
# ...

# %%
df.shape
# Out:
# (28, 12)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=28, step=1)

# %%
len(df)
# Out:
# 28

# %%
df.columns
# Out:
# Index(['index', 'Date', 'Week Day', 'Total Screen Time ', 'Social Networking',
#        'Reading and Reference', 'Other', 'Productivity', 'Health and Fitness',
#        'Entertainment', 'Creativity', 'Yoga'],
#       dtype='object')

# %%
df[['Date','Total Screen Time ', 'Week Day']][1:10]
# Out:
#        Date  Total Screen Time    Week Day
# 1  04/18/19                 123   Thursday
# 2  04/19/19                 112     Friday
# 3  04/20/19                 101   Saturday
# 4  04/21/19                  56     Sunday
# 5  04/22/19                 189     Monday
# 6  04/23/19                 158    Tuesday
# 7  04/24/19                 135  Wednesday
# 8  04/25/19                  52   Thursday
# 9  04/26/19                 198     Friday

# %%
df['Total Screen Time '].max()
# Out:
# np.int64(198)

# %%
df['Total Screen Time '].min()
# Out:
# np.int64(52)

# %%
df['Total Screen Time '].mean()
# Out:
# np.float64(113.25)

# %%
df['Total Screen Time '].median()
# Out:
# np.float64(111.0)

# %%
df['Total Screen Time '].std()
# Out:
# np.float64(43.562322320164775)

# %%
df['Total Screen Time '].mode()
# Out:
# 0    52
# 1    58
# Name: Total Screen Time , dtype: int64

# %%
df['Entertainment'].value_counts()
# Out:
# Entertainment
# 0     20
# 1      4
# 3      2
# 32     1
# 9      1
# Name: count, dtype: int64

# %%
# 25% 
df['Total Screen Time '].quantile(0.25)
# Out:
# np.float64(83.5)

# %%
df['Total Screen Time '].quantile(0.75)
# Out:
# np.float64(137.25)

# %%
df['Total Screen Time '].describe()
# Out:
# count     28.000000
# mean     113.250000
# std       43.562322
# min       52.000000
# 25%       83.500000
# 50%      111.000000
# 75%      137.250000
# max      198.000000
# Name: Total Screen Time , dtype: float64

# %%
# value Sorting
# df.sort_values('Total Screen Time ', ascending=False)
df['Total Screen Time '].sort_values(ascending=True)
# Out:
# 8      52
# 25     52
# 4      56
# 17     58
# 24     58
# 26     61
# 13     79
# 11     85
# 27     88
# 16     91
# 22     96
# 3     101
# 12    109
# 20    110
# 2     112
# 10    116
# 21    122
# 1     123
# 14    127
# 18    133
# 7     135
# 19    144
# 6     158
# 23    161
# 15    170
# 0     187
# 5     189
# 9     198
# Name: Total Screen Time , dtype: int64

# %%
df['Social Networking'].nlargest(5)
# Out:
# 18    109
# 7      98
# 23     93
# 14     90
# 0      89
# Name: Social Networking, dtype: int64

# %%
df.nlargest(10, 'Social Networking')
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 18     18  05/05/19     Sunday                 133                109
# 7       7  04/24/19  Wednesday                 135                 98
# 23     23  05/10/19     Friday                 161                 93
# 14     14  05/01/19  Wednesday                 127                 90
# 0       0  04/17/19  Wednesday                 187                 89
# 19     19  05/06/19     Monday                 144                 81
# 1       1  04/18/19   Thursday                 123                 78
# 9       9  04/26/19     Friday                 198                 76
# 10     10  04/27/19   Saturday                 116                 75
# 20     20  05/07/19    Tuesday                 110                 70
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 18                      5      1             3                   0
# ...

# %%
df.nsmallest(10, 'Social Networking')
# Out:
#     index      Date  Week Day  Total Screen Time   Social Networking  \
# 8       8  04/25/19  Thursday                  52                 25
# 25     25  05/12/19    Sunday                  52                 28
# 17     17  05/04/19  Saturday                  58                 34
# 4       4  04/21/19    Sunday                  56                 35
# 26     26  05/13/19    Monday                  61                 37
# 13     13  04/30/19   Tuesday                  79                 40
# 27     27  05/14/19   Tuesday                  88                 41
# 11     11  04/28/19    Sunday                  85                 42
# 22     22  05/09/19  Thursday                  96                 42
# 12     12  04/29/19    Monday                 109                 46
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 8                       7      3            16                   0
# 25                      1      1             6                   0
# ...

# %%
# conditional Statements
df['Social Networking'] > 70
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9      True
# 10     True
# 11    False
# 12    False
# 13    False
# 14     True
# 15    False
# 16    False
# 17    False
# 18     True
# 19     True
# 20    False
# 21    False
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27    False
# Name: Social Networking, dtype: bool

# %%
df[df['Social Networking'] > 70]
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 1       1  04/18/19   Thursday                 123                 78
# 7       7  04/24/19  Wednesday                 135                 98
# 9       9  04/26/19     Friday                 198                 76
# 10     10  04/27/19   Saturday                 116                 75
# 14     14  05/01/19  Wednesday                 127                 90
# 18     18  05/05/19     Sunday                 133                109
# 19     19  05/06/19     Monday                 144                 81
# 23     23  05/10/19     Friday                 161                 93
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                      17     41            22                   0
# 1                      17      8             9                   0
# ...

# %%
df[df['Week Day']== 'Wednesday']
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 7       7  04/24/19  Wednesday                 135                 98
# 14     14  05/01/19  Wednesday                 127                 90
# 21     21  05/08/19  Wednesday                 122                 53
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                      17     41            22                   0
# 7                       3     33            16                   0
# 14                      0     10             7                   0
# 21                     25     26            15                   0
#
#     Entertainment  Creativity  Yoga
# 0               0           0     0
# 7               0           0     0
# 14              0           0     1
# 21              0           0     1

# %%
df['Week Day'] == 'Sunday'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25     True
# 26    False
# 27    False
# Name: Week Day, dtype: bool

# %%
import matplotlib.pyplot as plt

# %%
# Plot specific columns
df.plot(x='Week Day', y='Total Screen Time ',kind='line')
plt.title('Line Plot')
plt.show()

# %%
df.plot(x='Week Day', y='Total Screen Time ', kind='bar')
plt.title('Bar Plot')
plt.show()

# %%
df.plot(x='Week Day', y='Total Screen Time ', kind='scatter')
plt.title('Scatter Plot')
plt.show()

# %%
df['Total Screen Time '].plot(kind='hist', bins=10)
plt.title('Histogram')
plt.show()

# %%
plt.savefig('plot.png')  # Save as PNG

# %%
df.columns
# Out:
# Index(['index', 'Date', 'Week Day', 'Total Screen Time ', 'Social Networking',
#        'Reading and Reference', 'Other', 'Productivity', 'Health and Fitness',
#        'Entertainment', 'Creativity', 'Yoga'],
#       dtype='object')

# %%
# Create a bar plot for multiple columns
df.plot(x='Week Day', y=['Total Screen Time ', 'Social Networking', 'Reading and Reference'], kind='bar')
plt.title('Comparison')
plt.xlabel('Time')
plt.ylabel('date')
plt.legend(title='Products')
plt.grid(axis='y')
plt.show()
